# %% [markdown]
# <a href="https://colab.research.google.com/github/tacianylima-santacruz/python_sis_26_2/blob/main/aula_08/aula_08_revis%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Questionário 01:
# Características da Linguagem Python, Variáveis, Tipagem:
# https://forms.gle/reAgzAsDcz7iE5j47

# %% [markdown]
# # Questionário 02:
#
# Entrada/Saída, Operadores, Conversão de Tipos e Manipulação de Strings:
# https://forms.gle/6pHxWMA4nxg4KuGP9

# %% [markdown]
# # print() e input()

# %%
print("Bem-vindo à estalagem do Pônei Saltitante! O que vai ser, mestre Hobbit? Uma caneca de cerveja?")
# Out:
# Bem-vindo à estalagem do Pônei Saltitante! O que vai ser, mestre Hobbit? Uma caneca de cerveja?

# %%
print("Bem-vindo à estalagem do Pônei Saltitante!")
print('O que vai ser, mestre Hobbit? Uma caneca de cerveja?')
# Out:
# Bem-vindo à estalagem do Pônei Saltitante!
# O que vai ser, mestre Hobbit? Uma caneca de cerveja?

# %%
print("Bem-vindo à estalagem do Pônei Saltitante! \nO que vai ser, mestre Hobbit? Uma caneca de cerveja?")
# Out:
# Bem-vindo à estalagem do Pônei Saltitante!
# O que vai ser, mestre Hobbit? Uma caneca de cerveja?

# %%
print ('''Bem-vindo à estalagem do Pônei Saltitante!
O que vai ser, mestre Hobbit? Uma caneca de cerveja?''')
# Out:
# Bem-vindo à estalagem do Pônei Saltitante!
# O que vai ser, mestre Hobbit? Uma caneca de cerveja?

# %%
# O Python faz a pergunta e guarda a resposta na variável 'heroi'
aventureiro = input("Diga-me o seu nome, viajante: ")

print("Ah, " + aventureiro + "! Eu estava esperando por você.")
print("Temos uma longa jornada até Mordor pela frente!")
# Out:
# Diga-me o seu nome, viajante: Xao Lin
# Ah, Xao Lin! Eu estava esperando por você.
# Temos uma longa jornada até Mordor pela frente!

# %% [markdown]
# # Operadores Relacionais

# %%
10>5
# Out:
# True

# %%
10>=10
# Out:
# True

# %%
10==5+4
# Out:
# False

# %%
10=10
# Out:
#   File "/tmp/ipykernel_589/2975699964.py", line 1
#     10=10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# # Operadores Artiméticos

# %%
servidores_tipo_1 = 10
servidores_tipo_2 = 5
print(servidores_tipo_1 + servidores_tipo_2)
# Out:
# 15

# %%
custo_servidor_tipo_1 = 1000.0
custo_servidor_tipo_2 = 500.5
print(custo_servidor_tipo_1 + custo_servidor_tipo_2)
# Out:
# 1500.5

# %%
media = (custo_servidor_tipo_1 + custo_servidor_tipo_2) / 2
print(media)
# Out:
# 750.25

# %%
media = (custo_servidor_tipo_1 + custo_servidor_tipo_2) // 2
print(media)
# Out:
# 750.0

# %%
resto = (custo_servidor_tipo_1 + custo_servidor_tipo_2) % 2
print(resto)
# Out:
# 0.5

# %%
area_sala_servidor_quadrada = 10.25**2
print(area_sala_servidor_quadrada, "m²")
# Out:
# 105.0625 m²

# %%
# Exemplo: Contar quantos requisitos foram cumpridos
tem_idade = True
pogou_ingresso = True
tem_documento = False

# Somando booleanos diretamente (1 + 1 + 0)
requisitos_atendidos = tem_idade + pogou_ingresso + tem_documento

print(tem_idade + pogou_ingresso + tem_documento)
# Out:
# 2

# %% [markdown]
# # Conversão de Tipos

# %%
primeiro_numero = input ("Digite um número:")
segundo_numero = input ("Digite outro número:")
print(primeiro_numero + segundo_numero)
# Out:
# Digite um número:5
# Digite outro número:5
# 55

# %%
# O input normal lê como texto. Colocamos o int() em volta para já converter.
nivel_personagem = int(input("Qual o nível atual do seu Personagem? "))

# Agora que é um número (int), podemos fazer contas!
novo_nivel = nivel_personagem + 1

# Como a conta já foi feita, convertemos o novo_nivel de volta para texto (str)
# para conseguirmos juntar (concatenar) com a frase usando o sinal de +
print ("Parabéns! Você ganhou XP e subiu para o nível " + str(novo_nivel) + "!")
# Out:
# Qual o nível atual do seu Personagem? 10
# Parabéns! Você ganhou XP e subiu para o nível 11!

# %%
primeiro_numero = int (input ("Digite um número:"))
segundo_numero = input ("Digite outro número:")
print(primeiro_numero + segundo_numero)
# Out:
# Digite um número:1
# Digite outro número:1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_589/1556533047.py in <cell line: 0>()
#       1 primeiro_numero = int (input ("Digite um número:"))
#       2 segundo_numero = input ("Digite outro número:")
# ----> 3 print(primeiro_numero + segundo_numero)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
primeiro_numero = input ("Digite um número:")
segundo_numero = input ("Digite outro número:")
print(primeiro_numero * segundo_numero)
# Out:
# Digite um número:1
# Digite outro número:1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_589/3785973292.py in <cell line: 0>()
#       1 primeiro_numero = input ("Digite um número:")
#       2 segundo_numero = input ("Digite outro número:")
# ----> 3 print(primeiro_numero * segundo_numero)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
primeiro_numero = int(input("Digite um número:"))
segundo_numero = input ("Digite outro número:")
print(primeiro_numero * segundo_numero)
# Out:
# Digite um número:5
# Digite outro número:a
# aaaaa

# %%
primeiro_numero = int(input("Digite um número:"))
segundo_numero = float(input("Digite outro número:"))
print(primeiro_numero + segundo_numero)
# Out:
# Digite um número:1
# Digite outro número:6.6
# 7.6

# %%
# Convertendo String para Inteiro
texto_numero = "42"
numero = int(texto_numero)
print(numero + 8)  # Saída: 50
# Out:
# 50

# %%
texto_para_inteiro = "Texto"
print(int(texto_para_inteiro))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_805/149269594.py in <cell line: 0>()
#       1 texto_para_inteiro = "Texto"
# ----> 2 print(int(texto_para_inteiro))
#
# ValueError: invalid literal for int() with base 10: 'Texto'

# %%
# Convertendo Booleano para Inteiro
print(int(True))   # Saída: 1
print(int(False))  # Saída: 0
# Out:
# 1
# 0

# %%
boleano = True
print(boleano)
texto = str(boleano)
print(texto)
inteiro = int(boleano)
print(inteiro)
decimal = float(boleano)
print(decimal)
boleano = bool(texto)
print(boleano)
# Out:
# True
# True
# 1
# 1.0
# True

# %%
# Convertendo Float para Inteiro (descarta as casas decimais)
preco = 19.99
preco_inteiro = int(preco)
print(preco_inteiro)  # Saída: 19
# Out:
# 19

# %% [markdown]
# # **Strings**

# %%
nome = "Gandalf"
local = 'Terra-Média'
ano = "2019"
local_ano = '''
Gandalf está na Terra-Média.
Ano: 2019.'''
print(nome,type(nome))
print(local,type(local))
print(ano,type(ano))
print(local_ano,type(local_ano))
# Out:
# Gandalf <class 'str'>
# Terra-Média <class 'str'>
# 2019 <class 'str'>
#
# Gandalf está na Terra-Média.
# Ano: 2019. <class 'str'>

# %% [markdown]
# # Concatenação

# %%
nome = "Gandalf"
sobrenome = "O Branco"
# O espaço " " vazio é adicionado para separar as palavras
nome_completo = nome + " " + sobrenome

print(nome_completo)
# Resultado Esperado: Gandalf O Branco
# Out:
# Gandalf O Branco

# %% [markdown]
# # Multiplicação

# %%
opcao_cardapio= "Spam "
quantidade_spam=int(input("Quantos Spam você quer? "))
total=opcao_cardapio*quantidade_spam
print(total)
# Out:
# Quantos Spam você quer? 65
# Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam Spam

# %% [markdown]
# # f-strings

# %%
nome = "Aragorn, filho de Arathorn, herdeiro de Isildur"
idade = 87

frase_sem_fstring = "Saudações, meu nome é " + nome + " e eu tenho " + idade + " anos."
# Misturando texto e números (variáveis) de forma simples
frase_com_fstring = f'Saudações, meu nome é {nome} e eu tenho {idade} anos.'

print(frase_sem_fstring)
print(frase_com_fstring)
# Resultado Esperado: Saudações, meu nome é Aragorn e eu tenho 87 anos.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_616/4247196743.py in <cell line: 0>()
#       2 idade = 87
#       3
# ----> 4 frase_sem_fstring = "Saudações, meu nome é " + nome + " e eu tenho " + idade + " anos."
#       5 # Misturando texto e números (variáveis) de forma simples
#       6 frase_com_fstring = f'Saudações, meu nome é {nome} e eu tenho {idade} anos.'
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Aspas dentro da string

# %%
# Sem o escape, isso gera um erro de sintaxe:
# mensagem = "Ela disse: "Olá!" para todos."

# Com o caractere de escape \":
mensagem = "Ela disse: \"Olá, Mundo!\" para todos."
mensagem2 = "Ela disse 'Olá, Mundo!' para todos."
mensagem3 = 'Ela disse "Olá, Mundo!" para todos.'
mensagem4 = '''Ela disse \"Olá, Mundo!\" para todos.'''
print(mensagem)
print(mensagem2)
print(mensagem3)
print(mensagem4)
# Out:
# Ela disse: "Olá, Mundo!" para todos.
# Ela disse 'Olá, Mundo!' para todos.
# Ela disse "Olá, Mundo!" para todos.
# Ela disse "Olá, Mundo!" para todos.

# %%
aspas_duplas=input("digite algo com aspas duplas: \"  \" ")
print(aspas_duplas)
aspas_simples=input("digite algo com aspas simples: \' \' ")
print(aspas_simples)
# Out:
# digite algo com aspas duplas: "  " "Teste"
# "Teste"
# digite algo com aspas simples: ' ' 'Teste'
# 'Teste'

# %% [markdown]
# # Sequência de caracteres

# %%
texto_strings = "Um Anel para a todos governar"

# Pegando a primeira letra
primeira_letra = texto_strings[0]

# Pegando a letra 'l' da segunda palavra
letra_seis = texto_strings[6]

# Mostrando que o espaço também conta como caractere!
letra_sete = texto_strings[7]

# Acessando de trás para frente (índice negativo)
ultima_letra = texto_strings[-1]

print(f"Primeira letra: {primeira_letra}")  # Saída: U
print(f"Letra no índice 6: {letra_seis}")    # Saída: l
print(f"Letra no índice 7: {letra_sete}")   # Saída:  (um espaço em branco)
print(f"Última letra: {ultima_letra}")      # Saída: r
# Out:
# Primeira letra: U
# Letra no índice 6: l
# Letra no índice 7:
# Última letra: r

# %% [markdown]
# # Recuperar substrings

# %%
texto_strings = "Um Anel para a todos governar"
primeira_palavra = texto_strings[:7]        # Do início até o índice 6
mensagem_principal = texto_strings[12:]     # Do índice 12 até o final
trecho_meio = texto_strings[7:12]           # Do índice 7 ao 11
trecho_sem_indice_definido = texto_strings[:]
print(f"Início: {primeira_palavra}")        # Saída: Um Anel
print(f"Fim: {mensagem_principal}")         # Saída: para a todos governar
print(f"Meio: {trecho_meio}")
print(f"Sem índice definido: {trecho_sem_indice_definido}")
# Out:
# Início: Um Anel
# Fim:  a todos governar
# Meio:  para
# Sem índice definido: Um Anel para a todos governar

# %% [markdown]
# # Lower, Upper, Capitalize e Inversão:

# %%
titulo = "o Senhor dos Anéis"
grito = "vocês não poderão passar!"
sussurro = "GOLLUM... meu precioso..."

# Transformando em maiúsculas (grito)
print(grito.upper())
# Transformando em minúsculas (sussurro)
print(sussurro.lower())
# Capitalizando (primeira letra maiúscula)
print(titulo.capitalize())

# Invertendo o texto usando fatiamento com passo negativo [::-1]
inscricao = "Um Anel para a todos governar"
texto_invertido = inscricao[::-1]

print(f"Inscrição ao contrário: {texto_invertido}")
# Saída: ranrevog sodot a arap lenA mU
# Out:
# VOCÊS NÃO PODERÃO PASSAR!
# gollum... meu precioso...
# O senhor dos anéis
# Inscrição ao contrário: ranrevog sodot a arap lenA mU

# %% [markdown]
# # len()

# %%
# A função len() conta a quantidade total de caracteres, incluindo espaços!

# Exemplo 1: O nome de um personagem
mago = "Gandalf, o Cinzento"
tamanho_nome = len(mago)

print(f"O nome '{mago}' possui {tamanho_nome} caracteres.")
# Saída: O nome 'Gandalf, o Cinzento' possui 19 caracteres.


# Exemplo 2: A fala icônica do Gollum
fala_gollum = "Meu precioso!"
tamanho_fala = len(fala_gollum)

print(f"A fala tem {tamanho_fala} letras e símbolos.")
# Saída: A fala tem 13 letras e símbolos.
# Out:
# O nome 'Gandalf, o Cinzento' possui 19 caracteres.
# A fala tem 13 letras e símbolos.

# %% [markdown]
# # Replace

# %%
# Texto original da profecia
texto_profecia = '''Um Anel para a todos governar, Um Anel para encontrá-los,
Um Anel para a todos trazer e na escuridão aprisioná-los na terra de Mordor.'''
local_profecia = input("Digite o local da profecia: ")
# Substituindo 'Mordor' por 'Gondor' ou modificando o nome do reino
# nova_profecia = texto_profecia.replace("Mordor", local_profecia)

print("\nCom Replace:")
print(texto_profecia.replace("Mordor", local_profecia))

print("Original:")
print(texto_profecia)
# Out:
# Digite o local da profecia: Curitiba
#
# Com Replace:
# Um Anel para a todos governar, Um Anel para encontrá-los,
# Um Anel para a todos trazer e na escuridão aprisioná-los na terra de Curitiba.
# Original:
# Um Anel para a todos governar, Um Anel para encontrá-los,
# Um Anel para a todos trazer e na escuridão aprisioná-los na terra de Mordor.

# %%
frase_sociedade = "Frodo carrega o Um Anel até a Montanha da Perdição."
portador_anel = input("Digite o nome do portador do anel: ")
# Substituindo Frodo
nova_frase = frase_sociedade.replace("Frodo", portador_anel)

print(nova_frase)
# Out:
# Digite o nome do portador do anel: Taciany
# Taciany carrega o Um Anel até a Montanha da Perdição.

# %% [markdown]
# # Split

# %%
# String recebida com os nomes separados por vírgula
lista_membros = "Frodo, Sam, Aragorn, Legolas, Gimli, Boromir, Gandalf"

# O split() divide a string a cada vírgula e cria uma lista de membros
membros_sociedade = lista_membros.split(", ")

print("Escolhido:")
print(f"- {membros_sociedade[2]}")
# Out:
# Escolhido:
# - Aragorn

# %%
# Redação enviada pelo membro Pippin
redacao = '''A batalha no Abismo de Helm foi decisiva para a vitoria
de Rohan contra as forças de Saruman.'''

# Sem argumentos, o split() divide por qualquer espaço em branco
palavras = redacao.split()

print("Palavras encontradas:", palavras)
print(f"Total de palavras na redação: {len(palavras)}")
print(f"Total de caracteres na redação: {len(redacao)}")
print(f"Palavra escolhida: {palavras[3]}")
# Out:
# Palavras encontradas: ['A', 'batalha', 'no', 'Abismo', 'de', 'Helm', 'foi', 'decisiva', 'para', 'a', 'vitoria', 'de', 'Rohan', 'contra', 'as', 'forças', 'de', 'Saruman.']
# Total de palavras na redação: 18
# Total de caracteres na redação: 93
# Palavra escolhida: Abismo

# %% [markdown]
# # Find

# %%
# Registro da ordem de chegada para pegar os livros sagrados
registro_biblioteca = "Presentes: Merry, Pippin, Frodo, Sam, Boromir"

# Procurando a posição de 'Frodo'
posicao_frodo = registro_biblioteca.find("Frodo")
print(f"Posição do primeiro caractere de 'Frodo': {posicao_frodo}")
# Out:
# Posição do primeiro caractere de 'Frodo': 26

# %%
redacao_membro = "Durante a Segunda Era, os elfos de Eregion criaram os Aneis do Poder com muita habilidade."

# O método find procura a substring
resultado = redacao_membro.find("Sauron")

print(f"Índice retornado: {resultado}")
# Out:
# Índice retornado: -1

# %% [markdown]
# # Count

# %%
# Histórico de presenças da semana gravado em um texto
historico_presenca = "Frodo, Sam, Frodo, Legolas, Frodo, Gimli, Sam"

# O count conta quantas vezes a palavra 'Frodo' aparece no texto
aulas_presente = historico_presenca.count("Frodo")

print("Dias em que Frodo esteve presente:", aulas_presente)
# Out:
# Dias em que Frodo esteve presente: 3

# %%
nome_membro = "Aragorn Filho de Arathorn"

# Conta a quantidade de letras 'a' (minúsculas)
quantidade_a = nome_membro.count("a")

print(f"O nome '{nome_membro}' possui a letra 'a' minúscula {quantidade_a} vezes.")
# Out:
# O nome 'Aragorn Filho de Arathorn' possui a letra 'a' minúscula 2 vezes.

# %% [markdown]
# # Strip

# %%
# A senha secreta da porta está toda em letras minúsculas e sem espaços
senha_secreta = "mellon"
# O jogador digita a senha no teclado (com espaços sobrando
entrada_jogador = "mellon  "
print("Sem tratamento:",senha_secreta == entrada_jogador)
# Sem limpar os dados, a porta continuaria fechada, pois "mellon  " é diferente de "mellon".

senha_tratada = entrada_jogador.strip()
print("Com tratamento:",senha_secreta == senha_tratada)
# Out:
# Sem tratamento: False
# Com tratamento: True

# %% [markdown]
# # ord() e chr()

# %%
numero_do_A = ord("A")
print(numero_do_A)
# Resultado: 65

numero_do_B = ord("B")
print(numero_do_B)
# Resultado: 66
# Out:
# 65
# 66

# %%
letra_65 = chr(65)
print(letra_65)
# Resultado: A

letra_97 = chr(97)
print(letra_97)
# Resultado: a (letras minúsculas têm números diferentes!)
# Out:
# A
# a

# %% [markdown]
# # **As Portas de Durin (a entrada para as minas de Moria)**
# A inscrição na porta mágica diz: "Fale, amigo, e entre". A senha correta para abrir a porta é a palavra "amigo" em élfico, que é "mellon".
#
# Imagine que você está criando um jogo de texto e o jogador precisa digitar essa senha. O jogador pode acabar digitando espaços a mais ou digitando letras maiúsculas.

# %%
# A senha secreta está toda em letras minúsculas e sem espaços
senha_secreta = "mellon"
# O jogador digita a senha no teclado (com espaços sobrando e letras maiúsculas)
entrada_jogador = "ME LLON "
print("Sem tratamento:",senha_secreta == entrada_jogador)
# Sem limpar os dados, a porta continuaria fechada
senha_tratada_parcial = entrada_jogador.strip()
print("Com tratamento parcial:",senha_secreta == senha_tratada_parcial)
# False ainda pois "MELLON" é diferente de "mellon".
# Vamos encadear o .strip() e o .lower() para tratar essa entrada:
senha_tratada = entrada_jogador.strip().lower()
print("Com tratamento completo",senha_secreta == senha_tratada)
# Out:
# Sem tratamento: False
# Com tratamento parcial: False
# Com tratamento completo False

# %% [markdown]
# # Formatando números

# %%
nota1 = 8.75
nota2 = 9.30
nota3 = 7.80

# Cálculo da média simples
media = (nota1 + nota2 + nota3) / 3
print(f"A média do aluno Samwise é: {media}")
# Uso do :.2f dentro da f-string para limitar as casas decimais
print(f"A média do aluno Samwise é: {media:.2f}")
# Out:
# A média do aluno Samwise é: 8.616666666666667
# A média do aluno Samwise é: 8.62

# %%
ouro_arrecadado = 1550000

# O uso de :, adiciona vírgula como separador de milhar (padrão norte-americano/python)
print(f"Total arrecadado para a biblioteca: {ouro_arrecadado:,} moedas de ouro.")

# Ou substituindo por ponto (padrão brasileiro)
formatado_br = f"{ouro_arrecadado:,}".replace(",", ".")
print(f"Formatado em PT-BR: R$ {formatado_br}")
# Out:
# Total arrecadado para a biblioteca: 1,550,000 moedas de ouro.
# Formatado em PT-BR: R$ 1.550.000

# %%
# Valor com milhares e centavos
ouro_arrecadado = 1550000.01

# 1. Formatamos no padrão americano: "1,550,000.01"
us_format = f"{ouro_arrecadado:,.2f}"

# 2. Invertemos os símbolos para o padrão PT-BR
br_format = us_format.replace(",", "X").replace(".", ",").replace("X", ".")

print(f"Total arrecadado: R$ {br_format}")
# Out:
# Total arrecadado: R$ 1.550.000,01

# %%
import locale

# Configura a localização para o Português do Brasil
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')

# Valor com milhares e centavos

valor = 1550000.01

# O parâmetro grouping=True garante a separação dos milhares
formatado_br = locale.currency(valor, symbol=True, grouping=True)

print(formatado_br)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_4641/1561726204.py in <cell line: 0>()
#       2
#       3 # Configura a localização para o Português do Brasil
# ----> 4 locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')
#       5
#       6 # Valor com milhares e centavos
#
# /usr/lib/python3.12/locale.py in setlocale(category, locale)
#     613         # convert to string
#     614         locale = normalize(_build_localename(locale))
# --> 615     return _setlocale(category, locale)
#     616
#     617 def resetlocale(category=LC_ALL):
#
# Error: unsupported locale setting

# %%
import subprocess

# Run the shell command to list all available locales
result = subprocess.run(['locale', '-a'], capture_output=True, text=True)

# Print the output (list of locales)
print("Locales disponíveis no ambiente Colab:")
print(result.stdout)
# Out:
# Locales disponíveis no ambiente Colab:
# C
# C.utf8
# en_US.utf8
# POSIX
# pt_BR.utf8

# %%
# O valor decimal representando a taxa de presença (85%)
presenca = 0.85

# O :.0% multiplica por 100 e formata sem casas decimais
print(f"Frequência do Sam: {presenca:.0%}")
# Out:
# Frequência do Sam: 85%

# %%
# Acertos no teste: 18 de 23 questões
taxa_acerto = 18 / 23  # Dá aproximadamente 0.782608...

# O :.2% formata com 2 casas decimais e o símbolo de %
print(f"Taxa de acerto do Frodo: {taxa_acerto:.2%}")
# Out:
# Taxa de acerto do Frodo: 78.26%

# %% [markdown]
# ### Instalando e configurando o locale `pt_BR.UTF-8`

# %%
# Primeiro, você precisa reconfigurar os pacotes de locale para garantir que o sistema possa gerar novos locales.
# Isso abrirá uma interface interativa, onde você deve selecionar 'pt_BR.UTF-8' e 'en_US.UTF-8' (se não estiverem já marcados).
# Para selecionar/desselecionar, use a barra de espaço. Pressione 'Tab' para ir para 'Ok' e 'Enter'.

# Note: This command is interactive and requires user input in the terminal.
# It might be necessary to run it in a separate Colab session or manually intervene.
# For a non-interactive way, consider editing '/etc/locale.gen' and then running 'locale-gen'.
# !sudo dpkg-reconfigure locales
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# Configuring locales
# -------------------
#
# Locales are a framework to switch between multiple languages and allow users to
# use their language, country, characters, collation order, etc.
#
# Please choose which locales to generate. UTF-8 locales should be chosen by
# default, particularly for new installations. Other character sets may be useful
# for backwards compatibility with older systems and software.
#
#   1. All locales                      252. gl_ES ISO-8859-1
#   2. C.UTF-8 UTF-8                    253. gl_ES.UTF-8 UTF-8
# ...

# %% [markdown]
# Agora, você pode tentar executar o código que usava `locale.setlocale` novamente. Se as etapas acima funcionaram, o erro `unsupported locale setting` não deverá mais ocorrer.

# %%
nome = "frodo bolseiro"; nome.upper(); print(nome)
# Out:
# frodo bolseiro

# %%
taxa = 0.7826
f"Taxa: {taxa * 100}%"
# Out:
# 'Taxa: 78.25999999999999%'

# %% [markdown]
# # Questionário 03:
#
# Estruturas de Controle (if/elif/else, match...case, loops) e Funções (parâmetros, retorno, escopos local e global):
# https://forms.gle/Q1kcDrKqLfNNM96FA

# %% [markdown]
# # Condições Lógicas

# %%
# O professor Gandalf registra a nota do aluno Bilbo:
nota_texto = "7"   # Tipo: str (String / Texto)
nota_numero = 7    # Tipo: int (Inteiro / Número)

# Comparando se a nota em texto é igual à nota em número:
resultado = (nota_texto == nota_numero)

print("Nota em texto:", type(nota_texto))
print("Nota em número:", type(nota_numero))
print("As duas variáveis são iguais?", resultado)

# %% [markdown]
# # Operadores lógicos

# %% [markdown]
# # Operador and

# %%
A = True
B = False

print (A and A)
print (A and B)
print (B and A)
print (B and B)

# %%
# Ambas as condições precisam ser True
tem_convite = True
esta_na_lista = True

# O acesso só é liberado se tiver convite E estiver na lista
acesso_liberado = tem_convite and esta_na_lista

print("Acesso liberado?", acesso_liberado)
# Saída: True

# %% [markdown]
# # Operador OR

# %%
tem_anel = False
e_o_gandalf = True

# Apenas UMA condição precisa ser True
acesso_liberado = tem_anel or e_o_gandalf

print("Acesso liberado?", acesso_liberado)
# Saída: True

# %%
A = True
B = False

print (A or A)
print (A or B)
print (B or A)
print (B or B)

# %% [markdown]
# # Operador not

# %%
A = True
B = False

print (not A)
print (not B)

# %%
# O operador 'not' inverte o valor booleano
choveu = False

#not False se torna True
passagem_segura = not choveu

print("Caminho seguro para a comitiva?", passagem_segura)
# Saída: True

# %% [markdown]
# # Operador XOR

# %%
A = True
B = False

print (A != A)
print (A != B)
print (B != A)
print (B != B)

# %%
A = True
B = False

print (A ^ A)
print (A ^ B)
print (B ^ A)
print (B ^ B,"\n")

# %% [markdown]
# # If

# %%
senha_digitada = input("Digite a senha, amigo: ")

# Comparando se o texto digitado é IGUAL ao esperado
if senha_digitada == "mellon":
    print("A porta se abre! Bem-vindo às Minas de Moria.")

# %% [markdown]
# # If/Else

# %%
senha_digitada = input("Digite a senha amigo: ")

# Comparando se o texto digitado é IGUAL ao esperado
if senha_digitada == "mellon":
    print("A porta se abre! Bem-vindo às Minas de Moria.")
else:
    print("Senha incorreta! A porta continua trancada.")

# %% [markdown]
# If, Elif, Else

# %%
senha_digitada = input("Digite a senha, amigo: ")

# Comparando se o texto digitado é IGUAL ao esperado
if senha_digitada == "mellon":
    print("A porta se abre! Bem-vindo às Minas de Moria.")
elif senha_digitada == "amigo":
    print("Não é bem isso")
else:
    print("Senha incorreta! A porta continua trancada.")

# %% [markdown]
# # match...case

# %%
personagem = input("Digite o nome do personagem: ").lower().strip()

match personagem:
    case "frodo" | "sam":
        print("Carrega o Um Anel.")
    case "aragorn":
        print("Passo Largo")
    case "legolas":
        print("Mestre dos arcos e flechas.")
    case "gimli":
        print("Guerreiro anão com seu machado.")
    case _:
        # O "_" funciona como o "default" (caso nenhum outro bata)
        print("Membro desconhecido da comitiva.")
# Out:
# Digite o nome do personagem: Aloy
# Membro desconhecido da comitiva.

# %% [markdown]
# # While

# %%
distancia_mordor = 3  # distância restante

# O bloco repete ENQUANTO a condição for True
while distancia_mordor > 0:
    print(f"Frodo andou. Faltam {distancia_mordor} km.")
    distancia_mordor -= 1  # Decrementa para evitar loop infinito

print("Frodo chegou à Montanha da Perdição!")

# %% [markdown]
# # For

# %%
palavra = "Python"

for letra in palavra:
    print(letra)

# %%
comitiva = ["Frodo", "Sam", "Aragorn", "Legolas"]

# Percorre cada elemento da lista
for membro in comitiva:
    print(f"Membro da comitiva: {membro}")

# %%
# Executa o bloco de código de 1 até 3
for dia in range(1, 4):
    print(f"Dia {dia}: A comitiva continua marchando...")

print("Chegaram ao destino final!")

# %% [markdown]
# # Break e Continue

# %%
for numero in range (1,10):
  if numero %2 == 0:
    continue
  print(f"Número Ímpar: {numero}")

# %%
print("Procurando o número 5...")

for numero in range(1, 11):
    print(f"Testando o número: {numero}")

    if numero == 5:
        print("Achei o 5! Parando o loop agora mesmo.")
        break  # O break destrói o loop na hora. O 6, 7, 8... nunca serão testados.

print("Fim da busca.")

# %% [markdown]
# # Estrutura de uma Função

# %% [markdown]
# Exemplo de uso

# %%
# O cliente colocou uma Camiseta no carrinho
preco_camiseta = 50.00
desconto_camiseta = preco_camiseta * 0.10
total_camiseta = preco_camiseta - desconto_camiseta

# O cliente colocou um Tênis no carrinho
preco_tenis = 200.00
desconto_tenis = preco_tenis * 0.10
total_tenis = preco_tenis - desconto_tenis

# O cliente colocou um Livro no carrinho
preco_livro = 40.00
desconto_livro = preco_livro * 0.10
total_livro = preco_livro - desconto_livro

# %%
# Você cria a função UMA VEZ:
def calcular_preco_final(preco, desconto):
    valor_do_desconto = preco * (desconto / 100)
    preco_final = preco - valor_do_desconto
    return preco_final

# %%
# O código do carrinho fica apenas assim:
total_camiseta = calcular_preco_final(50.00, 10)
total_tenis = calcular_preco_final(200.00, 10)
total_livro = calcular_preco_final(40.00, 10)

# %% [markdown]
# # Como usar

# %%
def nome_da_funcao(parametro):
    # Bloco de código
    return parametro * 2

# %%
def forjar_arma(arma, dono):
    print(f" A arma {arma} foi forjada com sucesso para {dono}!")

# %%
forjar_arma("Ferroada", "Frodo")
forjar_arma("Andúril", "Aragorn")

# %% [markdown]
# # Parâmetros e argumentos

# %%
# 'nome' é o PARÂMETRO
def saudar(nome):
    print(f"Olá, {nome}")

# 'Aragorn' é o ARGUMENTO
saudar("Aragorn")

# %%
# 'nome' é o PARÂMETRO
def saudar(nome):
    print(f"Olá, {nome}")

# 'Aragorn' é o ARGUMENTO
nome="Aragorn"
saudar(nome)

# %% [markdown]
# # Parâmetro padrão

# %%
# 'titulo' tem o valor padrão "Guerreiro"
def criar_personagem(nome, titulo="Guerreiro"):
    print(f"{nome}, o {titulo}")
criar_personagem("Legolas", "Elfo")  # Saída: Legolas, o Elfo
criar_personagem("Gimli")           # Saída: Gimli, o Guerreiro
nome="Gandalf"
titulo="Mago"
criar_personagem(nome, titulo)

# %% [markdown]
# # Argumento Nomeado

# %%
def criar_personagem(nome, classe, reino):
    print(f"{nome} é {classe} de {reino}")

# Chamada usando argumentos nomeados (fora da ordem original):
criar_personagem("Gondor", "Aragorn", "Guerreiro")
criar_personagem(reino="Gondor", nome="Aragorn", classe="Guerreiro")

# %% [markdown]
# # Múltiplos argumentos

# %%
# O *args recebe quantos nomes forem enviados
def convocar_comitiva(*membros):
    print("Membros convocados:")
    for membro in membros:
        print(f"- {membro}")

# Chamando com 3 argumentos
convocar_comitiva("Frodo", "Sam", "Gimli")

# %%
# O *args recebe quantos nomes forem enviados
def convocar_comitiva(*membros):
    print("Membros convocados:")
    for membro in membros:
        print(f"- {membro}")

# Chamando com 3 argumentos
convocar_comitiva("Frodo", "Sam", "Gimli")

# %% [markdown]
# # Múltiplos argumentos nomeados

# %%
# O **kwargs recebe características dinâmicas
def ficha_personagem(**atributos):
    for chave, valor in atributos.items():
        print(f"{chave.capitalize()}: {valor}")

# Chamando a função com diferentes argumentos nomeados
ficha_personagem(nome="Aragorn", classe="Ranger", reino="Gondor")

# %% [markdown]
# # Return

# %%
def enviar_mensagem(destinatario):
    return f"Fuja, seu tolo! Mandado para: {destinatario}"

# %%
def contar_flechas(alvos_atingidos):
    total = alvos_atingidos * 2
    return total

# %%
print(f'Legolas usou {contar_flechas(5)} flechas')

# %% [markdown]
# # Variáveis locais

# %%
def preparar_viagem():
    suprimentos = "Lembas"  # Variável Local
    print(f"Carregando: {suprimentos}")

preparar_viagem()
print(suprimentos)

# Tentar usar 'suprimentos' fora da função vai gerar erro:
# print(suprimentos)  -> NameError!

# %% [markdown]
# # Variáveis Globais

# %%
reino_principal = "Gondor"  # Variável Global

def mostrar_reino():
    # Acessa a variável global sem problemas
    print(f"Bem-vindo ao reino de {reino_principal}!")

mostrar_reino()
print(reino_principal)  # Também acessível no programa principal

# %% [markdown]
# # Alterando variáveis globais e aninhadas

# %%
ouro_do_reino = 100  # Variável Global

def gastar_ouro(quantidade):
    global ouro_do_reino  # Permite alterar a variável global
    ouro_do_reino -= quantidade

gastar_ouro(30)
print(f"Ouro restante: {ouro_do_reino}")  # Saída: Ouro restante: 70

# %%
def comitiva():
    membros = 9  # Variável da função externa

    def membro_caiu():
        nonlocal membros  # Modifica a variável da função pai (comitiva)
        membros -= 1

    membro_caiu()
    print(f"Membros restantes: {membros}")  # Saída: 8

comitiva()

# %% [markdown]
# # Lambda

# %%
# Função tradicional (com def)
def dobrar_dano(dano):
    return dano * 2

# Mesma lógica usando lambda
dobrar_dano_lambda = lambda dano: dano * 2

# Testando
print(dobrar_dano(50))
print(dobrar_dano_lambda(50))

# %% [markdown]
# # Documentando a função

# %%
def calcular_dano(forca, multiplicador=1.5):
    """
    Calcula o dano final do ataque do herói.

    Parâmetros:
    forca (int): Valor base de força do herói
    multiplicador (float): Bônus da arma (padrão 1.5)

    Retorna:
    float: Dano total do ataque
    """
    return forca * multiplicador


# Consultando a documentação da função no terminal/IDE
help(calcular_dano)

# %% [markdown]
# # Questionário 04:
#
# Estruturas de Dados Nativas em Python (Listas, Tuplas, Dicionários e Conjuntos):
# https://forms.gle/MBvqRyyx9X59tSMT7

# %% [markdown]
# # Listas

# %%
# Uma lista vazia
uma_das_listas = []

# %%
# Uma lista de brinquedos de gatos
brinquedos_gatos = ["varinha", "ratinho", "bolinha", "apontador laser", "arranhador"]

# %%
# Acesso via índices positivos e negativos
print("Primeiro brinquedo:", brinquedos_gatos[0])
print("Segundo brinquedo:", brinquedos_gatos[1])
print("Último brinquedo:", brinquedos_gatos[-1])
# Out:
# Primeiro brinquedo: bolinha
# Segundo brinquedo: bolinha
# Último brinquedo: bolinha

# %%
# Tentando acessar um índice que não existe
print("Índice Inexistente:", brinquedos_gatos[20])
print("Índice Inexistente:", brinquedos_gatos[-21])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2882/3500993451.py in <cell line: 0>()
#       1 # Tentando acessar um índice que não existe
# ----> 2 print("Índice Inexistente:", brinquedos_gatos[20])
#       3 print("Índice Inexistente:", brinquedos_gatos[-21])
#
# IndexError: list index out of range

# %%
# Modificando itens da lista
brinquedos_gatos[1] = "ratinho"
print("Lista de brinquedos atualizada:", brinquedos_gatos, sep="\n")
# Out:
# Lista de brinquedos atualizada:
# ['pena', 'ratinho', 'apontador laser', 'arranhador', 'caixa de papelão']

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
# Adicionando novos elementos
brinquedos_gatos.append("bolinha") # adiciona ao final
brinquedos_gatos.insert(0, "varinha") # adiciona na posição 0
print("Lista de brinquedos atualizada:", *brinquedos_gatos, sep="\n - ")
# Out:
# Lista de brinquedos atualizada:
#  - varinha
#  - pena
#  - ratinho
#  - apontador laser
#  - arranhador
#  - caixa de papelão
#  - bolinha

# %%
# Removendo elementos
brinquedos_gatos.remove("bolinha") # remove a primeira ocorrência
print("Lista de brinquedos atualizada:", brinquedos_gatos)
brinquedos_gatos.pop() # remove o último elemento
print("Lista de brinquedos atualizada:", brinquedos_gatos)
brinquedos_gatos.pop(0) # remove o elemento na posição 0
print("Lista de brinquedos atualizada:", brinquedos_gatos)
# Out:
# Lista de brinquedos atualizada: ['varinha', 'pena', 'ratinho', 'apontador laser', 'arranhador', 'caixa de papelão']
# Lista de brinquedos atualizada: ['varinha', 'pena', 'ratinho', 'apontador laser', 'arranhador']
# Lista de brinquedos atualizada: ['pena', 'ratinho', 'apontador laser', 'arranhador']

# %%
# Inverter a ordem da lista
brinquedos_gatos.reverse()
print("Lista de brinquedos invertida:", brinquedos_gatos, sep="\n")
# Out:
# Lista de brinquedos invertida:
# ['arranhador', 'apontador laser', 'ratinho', 'pena']

# %%
# Ordenando a lista
brinquedos_gatos.sort() # ordena em ordem alfabética
print("Lista de brinquedos ordenada:", brinquedos_gatos, sep="\n")
# Out:
# Lista de brinquedos ordenada:
# ['apontador laser', 'arranhador', 'pena', 'ratinho']

# %%
# Ordena em ordem alfabética inversa
brinquedos_gatos.sort(reverse=True)
print("Lista de brinquedos ordenada:", brinquedos_gatos)
# Out:
# Lista de brinquedos ordenada: ['ratinho', 'pena', 'arranhador', 'apontador laser']

# %%
# Fatiamento
print("1º e 2º brinquedo:", brinquedos_gatos[0:2], sep="\n")
print("3º e 4º brinquedo:", brinquedos_gatos[2:4], sep="\n")
brinquedos_favoritos = brinquedos_gatos[1:4] # índice 1 ao 3
print("Brinquedos favoritos:", brinquedos_favoritos, sep="\n")
# Out:
# 1º e 2º brinquedo:
# ['varinha', 'ratinho']
# 3º e 4º brinquedo:
# ['bolinha', 'apontador laser']
# Brinquedos favoritos:
# ['ratinho', 'bolinha', 'apontador laser']

# %%
# Comprimento da lista
total_brinquedos = len(brinquedos_gatos)
print("Total de brinquedos:", total_brinquedos)
print("Index máximo:", total_brinquedos - 1)
# Out:
# Total de brinquedos: 5
# Index máximo: 4

# %%
# Verificando a existênca de um item
item_existente = "apontador laser" in brinquedos_gatos
print("Item existente:", item_existente)
# Out:
# Item existente: True

# %%
if "apontador laser" in brinquedos_gatos:
    print("Hora de brincar!")
else:
    print("Hora de descansar!")
# Out:
# Hora de brincar!

# %%
print ("Lista de brinquedos:", brinquedos_gatos)
# Out:
# Lista de brinquedos: ['ratinho', 'bolinha', 'apontador laser', 'arranhador']

# %%
brinquedos_gatos.append("varinha")
print ("Lista de brinquedos:", brinquedos_gatos)
# Out:
# Lista de brinquedos: ['ratinho', 'bolinha', 'apontador laser', 'arranhador', 'bolinha', 'varinha', 'varinha']

# %%
# Removendo com Condição
if "caixa de papelão" in brinquedos_gatos:
    brinquedos_gatos.remove("caixa de papelão")
    print("A não, ela jogou a caixa fora.")
else:
    print("Caixa de papelão não está na lista de brinquedos.")
# Out:
# Caixa de papelão não está na lista de brinquedos.

# %%
# Removendo com Loop
for brinquedo in brinquedos_gatos:
    if brinquedo == "varinha":
        brinquedos_gatos.remove(brinquedo)
        print("Removido:", brinquedo)
    else:
        print("Não removido:", brinquedo)

print("Lista de brinquedos atualizada:", brinquedos_gatos)
# Out:
# Não removido: ratinho
# Não removido: bolinha
# Não removido: apontador laser
# Não removido: arranhador
# Não removido: bolinha
# Removido: varinha
# Lista de brinquedos atualizada: ['ratinho', 'bolinha', 'apontador laser', 'arranhador', 'bolinha', 'varinha']

# %%
# Removendo com Loop e cópia da lista
for brinquedo in brinquedos_gatos[:]:
    if brinquedo == "varinha":
        brinquedos_gatos.remove(brinquedo)
        print("Removido:", brinquedo)
    else:
        print("Não removido:", brinquedo)

print("Lista de brinquedos atualizada:", brinquedos_gatos)
# Out:
# Não removido: ratinho
# Não removido: bolinha
# Não removido: apontador laser
# Não removido: arranhador
# Não removido: bolinha
# Removido: varinha
# Removido: varinha
# Lista de brinquedos atualizada: ['ratinho', 'bolinha', 'apontador laser', 'arranhador', 'bolinha']

# %%
# Limpar a lista
brinquedos_gatos.clear() # limpa a lista
print("Lista de brinquedos vazia:", brinquedos_gatos)
# Out:
# Lista de brinquedos vazia: []

# %% [markdown]
# # Tuplas

# %%
# Uma tupla vazia
uma_das_tuplas = ()

# %%
# Tupla com informações
info_gatos = ("Batatinha", 12, "Cinza")

# %%
# Não é uma tupla
nao_e_uma_tupla = ("Batatinha")
print(type(nao_e_uma_tupla))
# Maneira correta de criar uma tupla de item único
tupla_com_um_elemento = ("Batatinha",)
print(type(tupla_com_um_elemento))
# Out:
# <class 'str'>
# <class 'tuple'>

# %%
# Tupla sem parenteses
tupla_sem_parenteses = "Batatinha", 1, "Cinza"
print(type(tupla_sem_parenteses))
# Out:
# <class 'tuple'>

# %%
# Acessa itens da tupla por índice
print("Nome:", info_gatos[0])
print("Idade:", info_gatos[1])
print("Cor:", info_gatos[2])
# Out:
# Nome: Batatinha
# Idade: 12
# Cor: Cinza

# %%
# Tentando alterar o item de uma tupla
info_gatos[1] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2882/2600664330.py in <cell line: 0>()
#       1 # Tentando alterar o item de uma tupla
# ----> 2 info_gatos[1] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Acessar itens da tupla
nome, idade, cor = info_gatos
print("Nome:", nome)
print("Idade:", idade)
print("Cor:", cor)
# Out:
# Nome: nome
# Idade: idade
# Cor: cor

# %%
# Acessar itens de uma lista
brinquedo01, brinquedo02, *outros_briquedos = brinquedos_gatos
print("Brinquedo 01:", brinquedo01)
print("Brinquedo 02:", brinquedo02)
print("Outros Brinquedos:", *outros_briquedos, sep="\n")
# Out:
# Brinquedo 01: varinha
# Brinquedo 02: ratinho
# Outros Brinquedos:
# bolinha
# apontador laser
# arranhador

# %%
# Quantidade e índice de elementos
print("Quantidade de informações:", len(info_gatos))
print("Índice do elemento 'Batatinha':", info_gatos.index("Batatinha"))
print("Quantidade de vezes que 'Batatinha' aparece:", info_gatos.count("Batatinha"))
# Out:
# Quantidade de informações: 3
# Índice do elemento 'Batatinha': 0
# Quantidade de vezes que 'Batatinha' aparece: 1

# %% [markdown]
# # Dicionários

# %%
# Um dicionário vázio
um_dos_dicionarios = {}

# %%
# Dicionário com informações
atributos_gatos = {
    "nome": "Batatinha",
    "idade": 12,
    "cor": "Cinza",
    "comida favorita": "Ração"
    }

# %%
# Acessando itens
print("Nome:", atributos_gatos["nome"])
print("Idade:", atributos_gatos["idade"])
print("Cor:", atributos_gatos["cor"])
print("Comida favorita:", atributos_gatos["comida favorita"])
# Out:
# Nome: Batatinha
# Idade: 12
# Cor: Cinza
# Comida favorita: Ração

# %%
# Tentando acessar uma chave inexistente
print("Raça:", atributos_gatos["raça"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2882/2126362242.py in <cell line: 0>()
#       1 # Tentando acessar uma chave inexistente
# ----> 2 print("Raça:", atributos_gatos["raça"])
#
# KeyError: 'raça'

# %%
# Acessando uma chave com get
print("Nome:", atributos_gatos.get("nome"))
print("Raça:", atributos_gatos.get("raça"))
# Out:
# Nome: Batatinha
# Raça: None

# %%
# Especificar retorno do get
print("Nome:", atributos_gatos.get("nome", "Não encontrado"))
print("Raça:", atributos_gatos.get("raça", "Não encontrado"))
# Out:
# Nome: Batatinha
# Raça: Não encontrado

# %%
# Adicionando chave
atributos_gatos["hobby"] = "Soneca"
print("Hobby:", atributos_gatos["hobby"])
#
# Out:
# Hobby: Soneca

# %%
# Alterando chave
atributos_gatos["comida favorita"] = "Caldinho de Frango"
print("Comida favorita:", atributos_gatos["comida favorita"])
#
# Out:
# Comida favorita: Caldinho de Frango

# %%
# Removendo chaves
comida_favorita = atributos_gatos.pop("comida favorita")
del atributos_gatos["cor"]
print("Comida favorita removida:", comida_favorita)
print("Cor removida:", atributos_gatos.pop("cor"))
print("Dicionário atualizado:", atributos_gatos)
#
# Out:
# Comida favorita removida: Caldinho de Frango
# Dicionário atualizado: {'nome': 'Batatinha', 'idade': 12, 'hobby': 'Soneca'}

# %%
# Todas as chaves
lista_chaves = list(atributos_gatos.keys())
print("Todas as chaves:", lista_chaves)
print("Tipo:", type(lista_chaves))
# Out:
# Todas as chaves: ['nome', 'idade', 'hobby']
# Tipo: <class 'list'>

# %%
# Todos os valores
lista_valores = list(atributos_gatos.values())
print("Todos os valores:", lista_valores)
print("Tipo:", type(lista_valores))
# Out:
# Todos os valores: ['Batatinha', 12, 'Soneca']
# Tipo: <class 'list'>

# %%
# Todas as chaves e valores
lista_chaves_valores = list(atributos_gatos.items())
print("Todas as chaves e valores:", lista_chaves_valores)
print("Tipo:", type(lista_chaves_valores))
print("Primeiro item:", lista_chaves_valores[0])
print("Tipo:", type(lista_chaves_valores[0]))
#
# Out:
# Todas as chaves e valores: [('nome', 'Batatinha'), ('idade', 12), ('hobby', 'Soneca')]
# Tipo: <class 'list'>
# Primeiro item: ('nome', 'Batatinha')
# Tipo: <class 'tuple'>

# %%
# Checando a existência de chaves
print("nome" in atributos_gatos)
print("raça" in atributos_gatos)
print("hobby" in atributos_gatos)
#
# Out:
# True
# False
# True

# %%
if "raça" in atributos_gatos:
    print("Raça:", atributos_gatos["raça"])
else:
    print("Raça não encontrada")
# Out:
# Raça não encontrada

# %% [markdown]
# # Conjuntos

# %%
# Criando um conjunto
um_dos_conjuntos = {1, 2, 3, 4, 5}

# %%
brinquedos_gatos.append("bolinha")

# %%
# Criando um conjunto a partir de uma lista
print ("Lista de brinquedos:", *brinquedos_gatos, sep="\n - ")
conjunto_de_brinquedos = set(brinquedos_gatos)
print ("Conjunto de brinquedos:", *conjunto_de_brinquedos, sep="\n - ")
# Out:
# Lista de brinquedos:
#  - varinha
#  - ratinho
#  - bolinha
#  - apontador laser
#  - arranhador
#  - bolinha
# Conjunto de brinquedos:
#  - ratinho
#  - varinha
#  - arranhador
#  - apontador laser
#  - bolinha

# %%
# Adicionando elemento
conjunto_de_brinquedos.add("bola")
print ("Conjunto de brinquedos atualizado:", *conjunto_de_brinquedos, sep="\n - ")
# Out:
# Conjunto de brinquedos atualizado:
#  - bola
#  - ratinho
#  - varinha
#  - arranhador
#  - apontador laser
#  - bolinha

# %%
# Removendo elemento
conjunto_de_brinquedos.remove("bola")
print ("Conjunto de brinquedos atualizado:", *conjunto_de_brinquedos, sep="\n - ")
# Out:
# Conjunto de brinquedos atualizado:
#  - ratinho
#  - varinha
#  - arranhador
#  - apontador laser
#  - bolinha

# %%
# Removendo elemento que pode não existir
conjunto_de_brinquedos.discard("bola")
print ("Conjunto de brinquedos atualizado:", *conjunto_de_brinquedos, sep="\n - ")
# Out:
# Conjunto de brinquedos atualizado:
#  - ratinho
#  - varinha
#  - arranhador
#  - apontador laser
#  - bolinha

# %%
# Operação matemática com conjuntos
caixa_brinquedos_01 = {"bolinha", "varinha de fitas", "apontador laser"}
caixa_brinquedos_02 = {"apontador laser", "pena", "arranhador"}

# %%
# Verificando a existência de itens
print("bolinha" in caixa_brinquedos_01)
print("bolinha" in caixa_brinquedos_02)
# Out:
# True
# False

# %%
# União do conjuntos
todos_os_brinquedos = caixa_brinquedos_01.union(caixa_brinquedos_02)
print("Todos os brinquedos:", todos_os_brinquedos)
# Out:
# Todos os brinquedos: {'arranhador', 'varinha de fitas', 'apontador laser', 'pena', 'bolinha'}

# %%
# Interseção
brinquedos_em_comum = caixa_brinquedos_01.intersection(caixa_brinquedos_02)
print("Brinquedos em comum:", brinquedos_em_comum)
# Out:
# Brinquedos em comum: {'apontador laser'}

# %%
# Diferença
brinquedos_em_caixa_01 = caixa_brinquedos_01.difference(caixa_brinquedos_02)
brinquedos_em_caixa_02 = caixa_brinquedos_02.difference(caixa_brinquedos_01)
print("Brinquedos em somente em caixa 01:", brinquedos_em_caixa_01)
print("Brinquedos em somente em caixa 02:", brinquedos_em_caixa_02)
# Out:
# Brinquedos em somente em caixa 01: {'varinha de fitas', 'bolinha'}
# Brinquedos em somente em caixa 02: {'arranhador', 'pena'}

# %% [markdown]
# # Questionário 05:
#
# Tratamento de Erros, Exceções (try/except/else/finally), Tracebacks e Técnicas de Depuração (Debugging):
# https://forms.gle/TRpk7URyDPw1bjmV8

# %% [markdown]
# # Entendendo mensagem de erros

# %%
cat_attributes = {
    "name": "Batatinha",
    "age": 1,
    "color": "grey",
    }
breed = cat_attributes["breed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1103/1525703180.py in <cell line: 0>()
#       4     "color": "grey",
#       5     }
# ----> 6 breed = cat_attributes["breed"]
#
# KeyError: 'breed'
# > /tmp/ipykernel_1103/1525703180.py(6)<cell line: 0>()
#       2     "name": "Batatinha",
#       3     "age": 1,
#       4     "color": "grey",
#       5     }
# ----> 6 breed = cat_attributes["breed"]
#
# ipdb>

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
    for pet in pets:
        if pet['name'] == name:
            pet['fed'] = True
            print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
  for pet in pets:
     print(f"Checking pet: {pet['name']}")
     if pet['name'] == name:
         pet['fed'] = True
         print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation
# Out:
# Checking pet: Batatinha
# Checking pet: Chai
# Checking pet: Axel

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
    for pet in pets:
        print(f"Checking pet: {pet['name']}")
        if pet['name'] == name:
            print(f"In if block: {pet['name']}")
            pet['fed'] = True
            print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation
# Out:
# Checking pet: Batatinha
# Checking pet: Chai
# Checking pet: Axel

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
    for pet in pets:
        print(f"Checking pet: {pet['name']} and {name}")
        if pet['name'] == name:
            print(f"In if block: {pet['name']}")
            pet['fed'] = True
            print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation
# Out:
# Checking pet: Batatinha and chai
# Checking pet: Chai and chai
# Checking pet: Axel and chai

# %%
# %pdb OFF
# Out:
# Automatic pdb calling has been turned OFF

# %%
# %debug
# Out:
# > /tmp/ipykernel_1103/1525703180.py(6)<cell line: 0>()
#       2     "name": "Batatinha",
#       3     "age": 1,
#       4     "color": "grey",
#       5     }
# ----> 6 breed = cat_attributes["breed"]
#
# ipdb>

# %%
print(age)

# %%
age = 2
print(age)

# %%
try:
  print("Bom Trabalho,", name)
except:
  print("A não, algo deu errado")
# Out:
#   File "/tmp/ipykernel_1103/1031149831.py", line 2
#     print("Great job so far,", name)
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1

# %%
try:
  print("Bom Trabalho,", name)
except NameError:
  print("A não, algo deu errado")

# %%
try:
  name = "Batatinha"
  print("Bom Trabalho,", name)
except:
  print("A não, algo deu errado")
else:
  print("Woohoo, all went well")
# Out:
# Great job so far, Batatinha
# Woohoo, all went well

# %%
try:
  name = "Batatinha"
  print("Bom Trabalho,", name)
except:
  print("A não, algo deu errado")
else:
  print("Uhul, Deu Certo")
finally:
  print("Você verá essa mensagem, com erro ou não")
# Out:
# Bom Trabalho, Batatinha
# Uhul, Deu Certo
# Você verá essa mensagem, com erro ou não

# %%
try:
  name = "Batatinha"
  print("Bom Trabalho,", name)
except:
  print("A não, algo deu errado")
finally:
  print("Você verá essa mensagem, com erro ou não")

# %%
try:
  with open("planos_secretos.txt", "r") as file:
    data = file.read()
  print(data)
except FileNotFoundError:
  print("Planos secretos não encontrados. Provávelmente estão bem guardados.")

# %%
try:
  with open("planos_secretos.txt", "r") as file:
     data = file.read()
  print(data)
except FileNotFoundError:
  print("Planos secretos não encontrados. Provávelmente estão bem guardados.")
except PermissionError:
  print("Você não tem permissão para acessas os segredos.")
