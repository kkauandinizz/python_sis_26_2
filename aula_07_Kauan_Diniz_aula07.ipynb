# %% [markdown]
# <a href="https://colab.research.google.com/github/kkauandinizz/python_sis_26_2/blob/kauan_diniz/aula_07_Kauan_Diniz_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome_heroi = "Batman"
print("O herói que vai salvar a cidade é o " + nome_heroi)
#print exibia "nome_heroi_cidade"
# Out:
# O herói que vai salvar a cidade é o Batman

# %%
idade_pet = 5
mensagem = f"A idade do meu cachorro é  + {idade_pet} +  anos."
print(mensagem)
# Out:
# A idade do meu cachorro é  + 5 +  anos.

# %%
print("Calculadora de Dobro!")
# Simulando alguém que digitou a palavra 'dez' em vez do número 10
numero_digitado = "10"
dobro = int(numero_digitado) * 2
print("O dobro é:", dobro)
# Out:
# Calculadora de Dobro!
# O dobro é: 20

# %%
cat_attributes = {
    "name": "Zia",
    "age": 1,
    "color": "grey",
    "breed": "de rua"

}

# Tentando descobrir a raça (breed) da gata
raca_gato = cat_attributes["breed"]
print("A raça da gata é:", raca_gato)
# Out:
# A raça da gata é: de rua

# %%
some_numbers = [10, 20, 30]

# Tentando acessar o quarto número da lista
quarto_numero = some_numbers[-1]
print("O número escolhido foi:", quarto_numero)
# Out:
# O número escolhido foi: 30

# %%
tesouro_moedas = 100
aventureiros_sobreviventes = 2

print("Calculando a divisão do tesouro...")

moedas_por_pessoa = tesouro_moedas / aventureiros_sobreviventes

print("Cada aventureiro vai receber:", moedas_por_pessoa)
# Out:
# Calculando a divisão do tesouro...
# Cada aventureiro vai receber: 50.0

# %%
print("=== Sistema do Zoológico ===")
# horário, alimento, quantidade
dieta_axolote = ["08:00", "minhocas", 50]

print("O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!")

dieta_axolote[1] = "pizza de calabresa"

print("Nova dieta:", dieta_axolote)
# Out:
# === Sistema do Zoológico ===
# O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!
# Nova dieta: ['08:00', 'pizza de calabresa', 50]

# %%
def contagem_regressiva(tempo):

    if tempo <= 0:
        print("BOOM! O Anel explodiu!")
        return

    print(f"Faltam {tempo} segundos...")

    # Passo Recursivo: A função chama a si mesma
    contagem_regressiva(tempo - 1)

print("Iniciando contagem para a explosão do Anel...")
contagem_regressiva(3)
# Out:
# Iniciando contagem para a explosão do Anel...
# Faltam 3 segundos...
# Faltam 2 segundos...
# Faltam 1 segundos...
# BOOM! O Anel explodiu!

# %%
def nap_time(hours_list):
    total = 0
    counter = 1
    while counter < len(hours_list):
      breakpoint()
      total += hours_list[counter]
      counter += 1
    return total
cat_naps = [2, 3, 1.5, 4]
print("Total nap time:", nap_time(cat_naps))
# Out:
# > /tmp/ipykernel_1697/3974802881.py(5)nap_time()
#       3     counter = 1
#       4     while counter < len(hours_list):
# ----> 5       breakpoint()
#       6       total += hours_list[counter]
#       7       counter += 1
#
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# > /tmp/ipykernel_1697/3974802881.py(5)nap_time()
#       3     counter = 1
#       4     while counter < len(hours_list):
# ----> 5       breakpoint()
#       6       total += hours_list[counter]
#       7       counter += 1

# %%
def average_meows(logs):
    total_meows_per_hour = 0
    valid_days = 0  # Vamos contar apenas os dias em que o gato ficou acordado

    for log in logs:
        nap_hours = 0

        for nap in log["naps"]:
            nap_hours += nap

        awake_hours = 24 - nap_hours

        # Só fazemos a divisão se o gato passou alguma hora acordado
        if awake_hours > 0:
            total_meows_per_hour += log["meows"] / awake_hours
            valid_days += 1
        else:
            print(f"Aviso: O gato hibernou na {log['day']}! Ignorando este dia na média.")

    # Protegendo a média final também!
    if valid_days > 0:
        return total_meows_per_hour / valid_days
    else:
        return 0

logs = [
    {"day": "Monday", "naps": [1, 2, 5], "meows": 90},
    {"day": "Tuesday", "naps": [4, 3, 2], "meows": 75},
    {"day": "Wednesday", "naps": [8, 6, 9, 1], "meows": 9},
    {"day": "Thursday", "naps": [1, 1, 5, 7], "meows": 38},
    {"day": "Friday", "naps": [3, 3, 2, 8], "meows": 94},
    {"day": "Saturday", "naps": [4, 8, 3], "meows": 64},
    {"day": "Sunday", "naps": [3, 3, 2, 8], "meows": 37}
]

print("Média de miados por hora acordada:", average_meows(logs))

# %%
def total_distance(*segments):
    total = 0
    for length, unit in segments:
        # .strip() remove espaços nas pontas e .lower() deixa tudo minúsculo
        clean_unit = unit.strip().lower()

        if clean_unit == "m":
            total += length
        elif clean_unit == "km":
            total += length * 1000 # Para converter km em m, multiplicamos!

    print("Total distance:", total, "meters")

total_distance(
    (2.5, "km"),
    (400, "M"),
    (1.0, "km"),
    (800, "m"),
    (1.3, "KM"),
    (900, "m "),
    (1.1, "km")
)
