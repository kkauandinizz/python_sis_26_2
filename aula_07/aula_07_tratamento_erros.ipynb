# %% [markdown]
# <a href="https://colab.research.google.com/github/tacianylima-santacruz/python_sis_26_2/blob/main/aula_07/aula_07_tratamento_erros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entendendo mensagem de erros

# %%
cat_attributes = {
    "name": "Batatinha",
    "age": 1,
    "color": "grey",
    }
breed = cat_attributes["breed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1103/1525703180.py in <cell line: 0>()
#       4     "color": "grey",
#       5     }
# ----> 6 breed = cat_attributes["breed"]
#
# KeyError: 'breed'
# > /tmp/ipykernel_1103/1525703180.py(6)<cell line: 0>()
#       2     "name": "Batatinha",
#       3     "age": 1,
#       4     "color": "grey",
#       5     }
# ----> 6 breed = cat_attributes["breed"]
#
# ipdb>

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
    for pet in pets:
        if pet['name'] == name:
            pet['fed'] = True
            print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
  breakpoint()
  for pet in pets:
     print(f"Checking pet: {pet['name']}")
     if pet['name'] == name:
         pet['fed'] = True
         print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation
# Out:
# > /tmp/ipykernel_1103/2306002630.py(5)feed_pet()
#       3     pets.append(pet)
#       4 def feed_pet(pets, name):
# ----> 5   breakpoint()
#       6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
#
# ipdb> n
# > /tmp/ipykernel_1103/2306002630.py(6)feed_pet()
#       4 def feed_pet(pets, name):
#       5   breakpoint()
# ----> 6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#
# ipdb> s
# > /tmp/ipykernel_1103/2306002630.py(7)feed_pet()
#       5   breakpoint()
#       6   for pet in pets:
# ----> 7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#       9          pet['fed'] = True
#
# ipdb> n
# Checking pet: Batatinha
# > /tmp/ipykernel_1103/2306002630.py(8)feed_pet()
#       6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
# ----> 8      if pet['name'] == name:
#       9          pet['fed'] = True
#      10          print(f"{name} has been fed.")
#
# ipdb> n
# > /tmp/ipykernel_1103/2306002630.py(6)feed_pet()
#       4 def feed_pet(pets, name):
#       5   breakpoint()
# ----> 6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#
# ipdb> n
# > /tmp/ipykernel_1103/2306002630.py(7)feed_pet()
#       5   breakpoint()
#       6   for pet in pets:
# ----> 7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#       9          pet['fed'] = True
#
# ipdb> n
# Checking pet: Chai
# > /tmp/ipykernel_1103/2306002630.py(8)feed_pet()
#       6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
# ----> 8      if pet['name'] == name:
#       9          pet['fed'] = True
#      10          print(f"{name} has been fed.")
#
# ipdb> n
# > /tmp/ipykernel_1103/2306002630.py(6)feed_pet()
#       4 def feed_pet(pets, name):
#       5   breakpoint()
# ----> 6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#
# ipdb> n
# > /tmp/ipykernel_1103/2306002630.py(7)feed_pet()
#       5   breakpoint()
#       6   for pet in pets:
# ----> 7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#       9          pet['fed'] = True
#
# ipdb> n
# Checking pet: Axel
# > /tmp/ipykernel_1103/2306002630.py(8)feed_pet()
#       6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
# ----> 8      if pet['name'] == name:
#       9          pet['fed'] = True
#      10          print(f"{name} has been fed.")
#
# ipdb> n
# > /tmp/ipykernel_1103/2306002630.py(6)feed_pet()
#       4 def feed_pet(pets, name):
#       5   breakpoint()
# ----> 6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#
# ipdb> n
# --Return--
# None
# > /tmp/ipykernel_1103/2306002630.py(6)feed_pet()
#       4 def feed_pet(pets, name):
#       5   breakpoint()
# ----> 6   for pet in pets:
#       7      print(f"Checking pet: {pet['name']}")
#       8      if pet['name'] == name:
#
# ipdb> n
# --Call--
# > /usr/local/lib/python3.13/dist-packages/IPython/core/displayhook.py(252)__call__()
#     250         sys.stdout.flush()
#     251
# --> 252     def __call__(self, result=None):
#     253         """Printing with history cache management.
#     254
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/displayhook.py(258)__call__()
#     256         activated by setting the variable sys.displayhook to it.
#     257         """
# --> 258         self.check_for_underscore()
#     259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#
# ipdb> globals ()
# {'__name__': 'IPython.core.displayhook', '__doc__': 'Displayhook for IPython.\n\nThis defines a callable class that IPython uses for `sys.displayhook`.\n', '__package__': 'IPython.core', '__loader__': <_frozen_importlib_external.SourceFileLoader object at 0x7a256b44dcd0>, '__spec__': ModuleSpec(name='IPython.core.displayhook', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7a256b44dcd0>, origin='/usr/local/lib/python3.13/dist-packages/IPython/core/displayhook.py'), '__file__': '/usr/local/lib/python3.13/dist-packages/IPython/core/displayhook.py', '__cached__': '/usr/local/lib/python3.13/dist-packages/IPython/core/__pycache__/displayhook.cpython-313.pyc', '__builtins__': {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <bound method Kernel.raw_input of <google.colab._kernel.Kernel object at 0x7a2564bd17f0>>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Excepti ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits': Thanks to CWI, CNRI, BeOpen, Zope Corporation, the Python Software
# Foundation, and a cast of thousands for supporting Python
# development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object., 'execfile': <function execfile at 0x7a256a63ed40>, 'runfile': <function runfile at 0x7a256a59c040>, '__IPYTHON__': True, 'display': <function display at 0x7a256b508040>, 'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7a2564bd2660>>}, 'builtin_mod': <module 'builtins' (built-in)>, 'sys': <module 'sys' (built-in)>, '_io': <module 'io' (frozen)>, 'tokenize': <module 'IPython.lib.py311_tokenize' from '/usr/local/lib/python3.13/dist-packages/IPython/lib/py311_tokenize.py'>, 'Configurable': <class 'traitlets.config.configurable.Configurable'>, 'Instance': <class 'traitlets.traitlets.Instance'>, 'Float': <class 'traitlets.traitlets.Float'>, 'warn': <built-in function warn>, 'DisplayHook': <class 'IPython.core.displayhook.DisplayHook'>, 'CapturingDisplayHook': <class 'IPython.core.displayhook.CapturingDisplayHook'>, '__pdb_convenience_variables': {'_frame': <frame at 0x7a25316f42e0, file '/usr/local/lib/python3.13/dist-packages/IPython/core/displayhook.py', line 258, code __call__>}}
# ipdb> locals ()
# {'self': <ipykernel.displayhook.ZMQShellDisplayHook object at 0x7a2563a15160>, 'result': None}
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/displayhook.py(259)__call__()
#     257         """
#     258         self.check_for_underscore()
# --> 259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
#
# ipdb> n
# --Return--
# None
# > /usr/local/lib/python3.13/dist-packages/IPython/core/displayhook.py(259)__call__()
#     257         """
#     258         self.check_for_underscore()
# --> 259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
#
# ipdb> n
# --Return--
# None
# > /tmp/ipykernel_1103/2306002630.py(16)<cell line: 0>()
#      13 add_pet(my_pets, "Batatinha", 2, "cat")
#      14 add_pet(my_pets, "Chai", 7, "dog")
#      15 add_pet(my_pets, "Axel", 2, "axolotl")
# ---> 16 feed_pet(my_pets, "chai")
#      17 # End of user interface simulation
#
# ipdb> n
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3464)run_ast_nodes()
#    3462                     to_run.append((node, 'single'))
#    3463
# -> 3464                 for node,mode in to_run:
#    3465                     if mode == 'exec':
#    3466                         mod = Module([node], [])
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3477)run_ast_nodes()
#    3475
#    3476             # Flush softspace
# -> 3477             if softspace(sys.stdout, 0):
#    3478                 print()
#    3479
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3495)run_ast_nodes()
#    3493             return True
#    3494
# -> 3495         return False
#    3496
#    3497     def _async_exec(self, code_obj: types.CodeType, user_ns: dict):
#
# ipdb> n
# Internal StopIteration: False
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3257)run_cell_async()
#    3255                     interactivity = 'async'
#    3256
# -> 3257                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3258                        interactivity=interactivity, compiler=compiler, result=result)
#    3259
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3260)run_cell_async()
#    3258                        interactivity=interactivity, compiler=compiler, result=result)
#    3259
# -> 3260                 self.last_execution_succeeded = not has_raised
#    3261                 self.last_execution_result = result
#    3262
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3261)run_cell_async()
#    3259
#    3260                 self.last_execution_succeeded = not has_raised
# -> 3261                 self.last_execution_result = result
#    3262
#    3263                 # Reset this so later displayed values do not modify the
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3265)run_cell_async()
#    3263                 # Reset this so later displayed values do not modify the
#    3264                 # ExecutionResult
# -> 3265                 self.displayhook.exec_result = None
#    3266
#    3267         if store_history:
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3204)run_cell_async()
#    3202             )
#    3203
# -> 3204             with self.display_trap:
#    3205                 # Compile to bytecode
#    3206                 try:
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3199)run_cell_async()
#    3197         _run_async = False
#    3198
# -> 3199         with self.builtin_trap:
#    3200             cell_name = self.compile.cache(
#    3201                 cell, self.execution_count, raw_code=raw_cell
#
# ipdb> n
# > /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py(3267)run_cell_async()
#    3265                 self.displayhook.exec_result = None
#    3266
# -> 3267         if store_history:
#    3268             # Write output to the database. Does nothing unless
#    3269             # history output logging is enabled.
#
# ipdb> c

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
    for pet in pets:
        print(f"Checking pet: {pet['name']}")
        if pet['name'] == name:
            print(f"In if block: {pet['name']}")
            pet['fed'] = True
            print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation

# %%
def add_pet(pets, name, age, species):
    pet = {"name": name, "age": age, "species": species, "fed": False}
    pets.append(pet)
def feed_pet(pets, name):
    for pet in pets:
        print(f"Checking pet: {pet['name']} and {name}")
        if pet['name'] == name:
            print(f"In if block: {pet['name']}")
            pet['fed'] = True
            print(f"{name} has been fed.")
my_pets = []
# This would be done with a user interface in real life
add_pet(my_pets, "Batatinha", 2, "cat")
add_pet(my_pets, "Chai", 7, "dog")
add_pet(my_pets, "Axel", 2, "axolotl")
feed_pet(my_pets, "chai")
# End of user interface simulation
# Out:
# Checking pet: Zia and wiesje
# Checking pet: Wiesje and wiesje
# Checking pet: Axel and wiesje

# %%
# %pdb OFF
# Out:
# Automatic pdb calling has been turned OFF

# %%
# %debug
# Out:
# > /tmp/ipykernel_1103/1525703180.py(6)<cell line: 0>()
#       2     "name": "Batatinha",
#       3     "age": 1,
#       4     "color": "grey",
#       5     }
# ----> 6 breed = cat_attributes["breed"]
#
# ipdb>

# %%
print(age)

# %%
age = 2
print(age)

# %%
try:
  print("Bom Trabalho,", name)
except:
  print("A não, algo deu errado")
# Out:
#   File "/tmp/ipykernel_1103/1031149831.py", line 2
#     print("Great job so far,", name)
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1

# %%
try:
  print("Bom Trabalho,", name)
except NameError:
  print("A não, algo deu errado")

# %%
try:
  name = "Batatinha"
  print("Bom Trabalho,", name)
except:
  print("A não, algo deu errado")
else:
  print("Woohoo, all went well")
# Out:
# Great job so far, Batatinha
# Woohoo, all went well

# %%
try:
  name = "Batatinha"
  print("Bom Trabalho,", name)
except:
  print("A não, algo deu errado")
finally:
  print("Você verá essa mensagem, com erro ou não")

# %%
try:
  with open("planos_secretos.txt", "r") as file:
    data = file.read()
  print(data)
except FileNotFoundError:
  print("Planos secretos não encontrados. Provávelmente estão bem guardados.")

# %%
try:
  with open("planos_secretos.txt", "r") as file:
     data = file.read()
  print(data)
except FileNotFoundError:
  print("Planos secretos não encontrados. Provávelmente estão bem guardados.")
except PermissionError:
  print("Você não tem permissão para acessas os segredos.")
