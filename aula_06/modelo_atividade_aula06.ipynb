# %% [markdown]
# <a href="https://colab.research.google.com/github/tacianylima-santacruz/python_sis_26_2/blob/main/aula_06/modelo_atividade_aula06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade 01 Aula 06
# ## Qual estrutura de dados você usaria em cada uma das situações abaixo?
#
# 1.   Lista de Compras;
# 2.   Registro de Alunos e Notas;
# 3.   Registro de Alunos e Notas;
# 4.   Datas de eventos históricos;
# 5.   Identificar quais alunos de Python também estão matriculados na disciplina de desenvolvimento seguro.

# %% [markdown]
# Sua resposta:
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
# Digite seu código aqui

# %% [markdown]
# # Atividade Prática 01 Aula 06
# Animais Favoritos
#
# Objetivo: Crie uma lista com vários animais para realizar filtros:
# Filtros:
# 1. Mostre em tela seus animais favoritos;
# 2. Imprima a quantidade de animais da lista e a quantidade de animais favoritos;
# 3. Mostre qual é o primeiro animail favorito e o último;
# 4. Remova um dos animais da lista e imprima o resultado;
# 5. Adicione um ou mais animais na lista;
# 6. Verifique quantos animais temos agora;
# 8. Troque a ordem dos animais favoritos de acordo com sua preferência e imprima.

# %%
# Digite seu código aqui

# %% [markdown]
# # Atividade Prática 02 Aula 06
# O Cardápio Fixo do Axolote (Tuplas)
# * Objetivo: Como sabemos, as tuplas são coleções imutáveis, sendo o formato ideal para armazenar dados que não devem ser modificados acidentalmente. O axolote de estimação tem uma rotina de alimentação muito restrita!
# Atividades:
# 1. Crie uma tupla contendo três elementos de tipos variados: o horário da refeição (texto), o alimento principal (texto) e a quantidade de vitaminas (número).
# 2. Tente alterar o alimento principal da tupla para "pizza de calabresa".
# Delete a linha que causou o erro. Agora, utilize a técnica de desempacotamento de tuplas para extrair esses três valores e salvá-los em três variáveis independentes usando apenas 1 linha de código.
# 3. Imprima uma frase amigável usando as variáveis desempacotadas. Por exemplo: "Às 08:00, o axolote come minhocas com 50 vitaminas."

# %%
# Digite seu código aqui

# %% [markdown]
# Agenda Telefônica (Dicionários)
#
# Objetivo:
#
# 1. Crie um dicionário de contatos com alguns nomes (como chaves) e números de telefone (como valores);
# 2. Adicione um novo contato ao dicionário sem alterá-lo diretamente (na declaração original);
# 3. Verifique se o contato "Chai" existe nos contatos. Se não, adicione-a com um número de telefone inventado.;
# 4. Exclua um dos seus contatos do dicionário; use um método que não cause um erro se o contato não existir;
# 5. Imprima todos os nomes presentes no dicionário.
#
# OBS.:Para cada ação imprima o resultado.# Atividade Prática 03 Aula 06

# %%
# Digite seu código aqui

# %% [markdown]
# # Atividade Prática 04 Aula 06
# A Sacola do Clube do Livro (Conjuntos)
#
# Objetivo: Um conjunto (set) é uma estrutura que, por natureza, não permite elementos duplicados, sendo útil para remover duplicatas de coleções de dados automaticamente. Fui à feira de troca de livros com meus amigos e jogamos todos os livros que arrecadamos em uma grande sacola. Acabamos pegando várias cópias do mesmo livro!
#
# Atividades:
#
# 1. Crie uma lista inicial com cerca de 6 ou 7 títulos de livros, mas coloque de propósito uns 3 títulos repetidos (por exemplo: "Duna", "O Hobbit", "Duna", "Harry Potter", "O Hobbit").
# 2. Converta essa sua lista em um Conjunto para forçar o sistema a eliminar todas as cópias duplicadas em um passe de mágica.
# 3. Imprima o conjunto na tela. Note que o resultado final perdeu as repetições e que os itens provavelmente mudaram de lugar, já que os conjuntos não mantêm a ordem de inserção dos elementos!

# %%
# Digite seu código aqui

# %% [markdown]
# # Atividade Prática 05 Aula 06
#
# Banco de Dados de Biblioteca (Combinação de Tipos)
#
# Objetivo: Imagine que sua biblioteca local peça a você para organizar o catálogo de livros em um dicionário Python. Neste exercício, vamos focar em estruturar e escolher os tipos de dados certos:
#
# 1. Crie uma estrutura combinada que armazene informações detalhadas sobre os livros. (Exemplo: O dicionário principal tem o nome do livro como chave, e o valor é outro dicionário contendo o nome do autor, ano de publicação, uma lista de gêneros literários e se ele está disponível ou emprestado)
#
# Estas são as informações que precisamos armazenar sobre cada livro:
# * Título
# * Nome do autor, ano de nascimento e nacionalidade
# * Número de páginas
# * Disponibilidade
# * Membro da biblioteca que o pegou emprestado atualmente
# * Ano de publicação
# * Gêneros
# * Avaliação (1-5)
#
# Aqui estão alguns títulos de livros para você começar.
# Sinta-se à vontade para adicionar alguns livros que você pessoalmente adora.
#
# Título: Jane Eyre
# Autor: Charlotte Brontë, 1816, Britânica
# Número de páginas: 659
# Ano de publicação: 1847
# Gêneros: Ficção Vitoriana, Romance de Formação (Bildungsroman), Histórico
# Avaliação: 4.6
# Disponível: sim
#
# Título: Python Illustrated
# Autores: Zia van Putten, 2023, Holandesa - Maaike van Putten, 1991, Holandesa - Imke van Putten, 1997, Holandesa
# Número de páginas: 432
# Ano de publicação: 2026
# Gêneros: Informativo, Educação
# Avaliação: 5
# Disponível: não
# Emprestado para: Jacob
#
# Título: Se os gatos desaparecessem do mundo
# Autor: Genki Kawamura
# Número de páginas: 144
# Ano de publicação: 2012
# Gêneros: Ficção Literária, Realismo Mágico, Ficção Filosófica
# Avaliação: 4.2
# Disponível: não
# Emprestado para: Chai
#
# Se você quiser uma dica para começar este exercício, certifique-se de que os títulos sejam as chaves de nível superior do seu dicionário da biblioteca.
#
# Aqui estão algumas tarefas:
#
# Imprima uma lista de todos os títulos de livros que a biblioteca possui.
#
# Verifique se "Romance" é um gênero de "Python Illustrated" e imprima a resposta.
#
# Imprima a nacionalidade do autor de Jane Eyre.
#
# Chai devolveu o livro que pegou emprestado. Atualize os valores de  Se os gatos desaparecessem do mundo, de acordo.
#
# Verifique se Python Illustrated está disponível e imprima quem o pegou emprestado caso não esteja
